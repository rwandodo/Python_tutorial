# %% [markdown]
# # Jupyter intro

# %% [markdown]
# ### python lessin 1

# %%
x=5
x
# Out:
# 5

# %%
print (x)
# Out:
# 5

# %%
name = 'ahmed'

# %%
name
# Out:
# 'ahmed'

# %%
name = 7
name
# Out:
# 7

# %%
y = 6
z= x+y
z
# Out:
# 11

# %%
name
# Out:
# 'ahmed'

# %%
z
# Out:
# 11

# %% [markdown]
# $X+Y$

# %% [markdown]
# $\frac {X+Z}{X+Y}$

# %% [markdown]
# ![whatJU.png](attachment:whatJU.png)
